# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://www.flipkart.com/mobile-phones-store"

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
Soup=BeautifulSoup(response.text)

# %%
Soup
# Out:
# <!DOCTYPE html>
# ...

# %%
name=Soup.select("._1W9f5C div")

# %%
name
# Out:
# []

# %%
rating=Soup.select("._3LWZlK")

# %%
rating
# Out:
# []

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://www.imdb.com/list/ls500849058/"

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
Soup=BeautifulSoup(response.text)

# %%
Soup=BeautifulSoup(response.text)

# %%
name=Soup.select(".lister-item-header a")

# %%
name
# Out:
# [<a href="/title/tt10698680/">K.G.F: Chapter 2</a>,
#  <a href="/title/tt9179430/">Vikram</a>,
#  <a href="/title/tt10701074/">Ponniyin Selvan: I</a>,
#  <a href="/title/tt8178634/">RRR (Rise Roar Revolt)</a>,
#  <a href="/title/tt13028258/">A Thursday</a>,
#  <a href="/title/tt6277462/">Brahmastra Part One: Shiva</a>,
#  <a href="/title/tt11934846/">Badhaai Do</a>,
#  <a href="/title/tt11460992/">Runway 34</a>,
#  <a href="/title/tt7466810/">777 Charlie</a>,
#  <a href="/title/tt7529298/">Attack</a>,
#  <a href="/title/tt10811166/">The Kashmir Files</a>,
#  <a href="/title/tt9851854/">Major</a>,
#  <a href="/title/tt10083340/">Gangubai Kathiawadi</a>,
#  <a href="/title/tt13919802/">Anek</a>,
#  <a href="/title/tt9054970/">Doctor G</a>,
#  <a href="/title/tt8983228/">Jhund</a>,
#  <a href="/title/tt7624920/">No Means No</a>,
#  <a href="/title/tt10733228/">Gehraiyaan</a>,
#  <a href="/title/tt13449624/">Jug Jugg Jeeyo</a>,
#  <a href="/title/tt13364468/">Love Hostel</a>,
# ...

# %%
director=Soup.select(".text-muted a:nth-child(1)")

# %%
director
# Out:
# [<a href="/name/nm6073824/">Prashanth Neel</a>,
#  <a href="/name/nm7992231/">Lokesh Kanagaraj</a>,
#  <a href="/name/nm0711745/">Mani Ratnam</a>,
#  <a href="/name/nm1442514/">S.S. Rajamouli</a>,
#  <a href="/name/nm5880364/">Behzad Khambata</a>,
#  <a href="/name/nm2209781/">Ayan Mukerji</a>,
#  <a href="/name/nm2862844/">Harshavardhan Kulkarni</a>,
#  <a href="/name/nm0222426/">Ajay Devgn</a>,
#  <a href="/name/nm7882203/">Kiranraj K</a>,
#  <a href="/name/nm3214690/">Lakshya Raj Anand</a>,
#  <a href="/name/nm1892252/">Vivek Agnihotri</a>,
#  <a href="/name/nm3481620/">Sashi Kiran Tikka</a>,
#  <a href="/name/nm0080220/">Sanjay Leela Bhansali</a>,
#  <a href="/name/nm1025280/">Anubhav Sinha</a>,
#  <a href="/name/nm3310756/">Anubhuti Kashyap</a>,
#  <a href="/name/nm5616219/">Nagraj Manjule</a>,
#  <a href="/name/nm8885401/">Vikash Verma</a>,
#  <a href="/name/nm2439708/">Shakun Batra</a>,
#  <a href="/name/nm3262433/">Raj Mehta</a>,
# ...

# %%
import pandas as pd

# %%
movielist=pd.DataFrame(name,columns=["list"])

# %%
movielist
# Out:
#                                       list
# 0                         K.G.F: Chapter 2
# 1                                   Vikram
# 2                       Ponniyin Selvan: I
# 3                   RRR (Rise Roar Revolt)
# 4                               A Thursday
# 5               Brahmastra Part One: Shiva
# 6                               Badhaai Do
# 7                                Runway 34
# 8                              777 Charlie
# 9                                   Attack
# 10                       The Kashmir Files
# 11                                   Major
# 12                     Gangubai Kathiawadi
# 13                                    Anek
# 14                                Doctor G
# 15                                   Jhund
# 16                             No Means No
# 17                              Gehraiyaan
# 18                          Jug Jugg Jeeyo
# 19                             Love Hostel
# 20                               Thank God
# ...

# %%
movielist.to_csv("D:/movie.csv")
